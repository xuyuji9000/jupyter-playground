# %%
print ("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
data = pd.read_csv("US_Accidents_May19.csv")

# %%
data.set_index('ID')
# Out:
#              Source    TMC  Severity           Start_Time  \
# ID
# A-1        MapQuest  201.0         3  2016-02-08 05:46:00
# A-2        MapQuest  201.0         2  2016-02-08 06:07:59
# A-3        MapQuest  201.0         2  2016-02-08 06:49:27
# A-4        MapQuest  201.0         3  2016-02-08 07:23:34
# A-5        MapQuest  201.0         2  2016-02-08 07:39:07
# ...             ...    ...       ...                  ...
# A-2243935      Bing    NaN         2  2017-08-30 20:01:40
# A-2243936      Bing    NaN         2  2017-08-30 20:01:40
# A-2243937      Bing    NaN         3  2017-08-30 20:03:10
# A-2243938      Bing    NaN         4  2017-08-30 20:49:40
# A-2243939      Bing    NaN         4  2017-08-30 20:48:10
#
#                       End_Time  Start_Lat   Start_Lng    End_Lat     End_Lng  \
# ID
# A-1        2016-02-08 11:00:00  39.865147  -84.058723        NaN         NaN
# A-2        2016-02-08 06:37:59  39.928059  -82.831184        NaN         NaN
# ...

# %%
data.shape
# Out:
# (2243939, 49)

# %%
data.groupby('Source').size()
# Out:
# Source
# Bing              516762
# MapQuest         1702565
# MapQuest-Bing      24612
# dtype: int64
