# %%
import pandas as pd 
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd

# %matplotlib inline

# %%
street_map = gpd.read_file("./shapfiles/nyct2010_15b/nyct2010.shp")

# %%
fig,ax = plt.subplots(figsize = (15, 15))
street_map.plot(ax=ax)
